# %%
import pandas as pd
df=pd.read_csv("six_sector.unknown")
# df["Entry"]=df["Entry"].astype(str)
df
# df=pd.to_datetime(df["Entry"],format="%m/%y",dayfirst=True)
# df
# Out:
#     No.        Company                           Sector  \
# 0     5         PayTM^      Fintech - Payments & Wallet
# 1    14  PolicyBazaar^              Fintech - Insurance
# 2    18       BillDesk           Fintech - B2B Payments
# 3    28      Pine Labs  Fintech - PoS Payment Solutions
# 4    32       RazorPay        Fintech - Payment Gateway
# ..  ...            ...                              ...
# 64   59         upGrad          Edtech - Higher Studies
# 65   61       Eruditus     Edtech - Executive Education
# 66   66        Vedantu                           Edtech
# 67   83    LEAD School                           Edtech
# 68   97  PhysicsWallah                           Edtech
#
#     Entry Valuation^^ ($B)  Valuation ($B) 2018  Valuation ($B) 2019  \
# 0                      1.7                  1.6                  0.4
# 1                      1.0                  2.3                  0.0
# 2                      1.6                  0.3                  4.2
# ...

# %%
fintech=df["Sector"].str.contains("Fintech")
df_fintech=df[fintech]
df_fintech["Fintech"]="Fintech"

ecom=df["Sector"].str.contains("E-Commerce")
df_ecom=df[ecom]
df_ecom["E-Commerce"]="E-Commerce"

health=df["Sector"].str.contains("Healthtech")
df_health=df[health]
df_health["Healthtech"]="Healthtech"

saas=df["Sector"].str.contains("SaaS")
df_saas=df[saas]
df_saas["Sector"]="SaaS"

edtech=df["Sector"].str.contains("Edtech")
df_edtech=df[edtech]
df_edtech["Sector"]="Edtech"

market=df["Sector"].str.contains("Marketplace")
df_market=df[market]
df_market["Sector"]="Marketplace"
df_fintech
# Out:
# C:\Users\mridu\AppData\Local\Temp\ipykernel_14584\663631415.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fintech["Fintech"]="Fintech"
# C:\Users\mridu\AppData\Local\Temp\ipykernel_14584\663631415.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ecom["E-Commerce"]="E-Commerce"
# C:\Users\mridu\AppData\Local\Temp\ipykernel_14584\663631415.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
six_sector=pd.concat(objs=[df_fintech,df_ecom,df_health,df_saas,df_market,df_edtech])
six_sector.to_csv("six_sector")

# %%
six_sector
# Out:
#     No.        Company                           Sector  \
# 0     5         PayTM^      Fintech - Payments & Wallet
# 1    14  PolicyBazaar^              Fintech - Insurance
# 2    18       BillDesk           Fintech - B2B Payments
# 3    28      Pine Labs  Fintech - PoS Payment Solutions
# 4    32       RazorPay        Fintech - Payment Gateway
# ..  ...            ...                              ...
# 64   59         upGrad                           Edtech
# 65   61       Eruditus                           Edtech
# 66   66        Vedantu                           Edtech
# 67   83    LEAD School                           Edtech
# 68   97  PhysicsWallah                           Edtech
#
#     Entry Valuation^^ ($B)  Valuation ($B) 2018  Valuation ($B) 2019  \
# 0                      1.7                  1.6                  0.4
# 1                      1.0                  2.3                  0.0
# 2                      1.6                  0.3                  4.2
# ...
